# %% [markdown]
# # Data Visualization using seaborn

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Dataset

# %%
sales = pd.read_excel('Sales.xls')

# %%
sales.shape
# Out:
# (8390, 21)

# %%
sales.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01     Regular Air    -4.640        2.08  ...         Ruben Dartt
# 2      0.07     Regular Air  1054.820      107.53  ...       Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...       Liz Pelletier
# 4      0.04     Regular Air   -85.129        7.99  ...       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8390 entries, 0 to 8389
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                8390 non-null   int64
#  1   Order ID              8390 non-null   int64
#  2   Order Date            8390 non-null   datetime64[ns]
#  3   Order Priority        8390 non-null   object
#  4   Order Quantity        8390 non-null   int64
#  5   Sales                 8390 non-null   float64
#  6   Discount              8390 non-null   float64
#  7   Ship Mode             8390 non-null   object
#  8   Profit                8390 non-null   float64
#  9   Unit Price            8390 non-null   float64
#  10  Shipping Cost         8390 non-null   float64
#  11  Customer Name         8390 non-null   object
#  12  Province              8390 non-null   object
#  13  Region                8390 non-null   object
# ...

# %%
sales.describe()
# Out:
#             Row ID      Order ID  Order Quantity         Sales     Discount  \
# count  8390.000000   8390.000000     8390.000000   8390.000000  8390.000000
# mean   4195.500000  29932.999166       25.564601   1775.466315     0.049677
# std    2422.128713  17242.133927       14.481768   3585.180194     0.031817
# min       1.000000      3.000000        1.000000      2.240000     0.000000
# 25%    2098.250000  14989.500000       13.000000    142.962500     0.020000
# 50%    4195.500000  29811.500000       26.000000    449.295000     0.050000
# 75%    6292.750000  44539.250000       38.000000   1709.985000     0.080000
# max    8390.000000  59939.000000       50.000000  89061.050000     0.250000
#
#              Profit   Unit Price  Shipping Cost  Product Base Margin
# count   8390.000000  8390.000000    8390.000000          8327.000000
# mean     181.060342    89.354539      12.841080             0.512504
# std     1197.067399   290.479112      17.271407             0.135600
# ...

# %% [markdown]
# ## 1.Scatter plot (Relational data plot)

# %%
plot = sns.relplot(x='Sales', y='Profit',data=sales)
plot.fig.set_figwidth(5)
plot.fig.set_figheight(5)

# %%
# classifying based on type
sns.relplot(x='Sales', y='Profit',data=sales, hue='Order Priority', style='Order Priority')

# %%
sns.relplot(x='Sales', y='Profit',data=sales, hue='Order Priority', style='Ship Mode')

# %%
sns.relplot(x='Sales', y='Profit',data=sales, size='Discount')

# %%
sns.relplot(x='Sales', y='Profit',data=sales,hue='Order Priority', size='Discount', sizes=(10, 150))

# %%
sales.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01     Regular Air    -4.640        2.08  ...         Ruben Dartt
# 2      0.07     Regular Air  1054.820      107.53  ...       Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...       Liz Pelletier
# 4      0.04     Regular Air   -85.129        7.99  ...       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# ...

# %% [markdown]
# ## Multiple charts

# %%
sns.relplot(x='Sales', y='Profit', data=sales, col='Customer Segment', col_wrap=2)

# %%
sns.relplot(x='Sales', y='Profit', data=sales, col='Customer Segment', col_wrap=2, hue='Order Priority')

# %%
sns.relplot(x='Sales', y='Profit', data=sales, col='Customer Segment', col_wrap=2, hue='Ship Mode')

# %%
sns.relplot(x='Sales', y='Profit', data=sales, col='Customer Segment', row='Product Category', hue='Ship Mode')
# Double click on plot to expand

# %% [markdown]
# ## Scatter plots (categorical data plot)

# %%
sns.catplot(x='Ship Mode', y='Sales', data=sales)

# %%
sns.catplot(x='Ship Mode', y='Sales', data=sales, jitter=False)

# %%
sns.catplot(x='Ship Mode', y='Sales', data=sales.query('Profit > 1000'), jitter=False)

# %% [markdown]
# ## Swarm plot

# %%
sns.catplot(x='Ship Mode', y='Sales', data=sales.query('Profit > 500'), kind='swarm')

# %%
sns.catplot(y='Ship Mode', x='Sales', data=sales.query('Profit > 500'), kind='swarm')

# %% [markdown]
# ## Boxplot

# %%
sns.catplot(x='Product Category', y='Shipping Cost', data=sales, kind='box')

# %%
sns.catplot(x='Product Category', y='Shipping Cost', hue='Ship Mode', data=sales, kind='box')

# %%
sns.catplot(x='Product Category', y='Shipping Cost', hue='Ship Mode',hue_order=['Delivery Truck', 'Regular Air', 'Express Air'], data=sales, kind='box')

# %%
sns.catplot(x='Product Category', y='Shipping Cost', col='Ship Mode', data=sales, kind='box')

# %%
sns.catplot(x='Product Category', y='Shipping Cost', col='Ship Mode', row='Customer Segment', data=sales, kind='box')

# %% [markdown]
# ## Violin Plot

# %%
sns.catplot(x='Product Category', y='Shipping Cost', data=sales, kind='violin')

# %%
sns.catplot(x='Product Category', y='Shipping Cost',hue='Ship Mode', data=sales, kind='violin')

# %% [markdown]
# ## Bar chart

# %%
sns.catplot(x='Product Category', y='Sales', hue='Ship Mode', col='Customer Segment', col_wrap=2,data=sales, kind='bar')

# %% [markdown]
# ## Point plot

# %%
sns.catplot(x='Product Category', y='Sales', data=sales, kind='point')

# %%
sns.catplot(x='Product Category', y='Sales', data=sales, hue='Ship Mode', kind='point')

# %%
sns.catplot(x='Product Category', y='Sales', data=sales,col='Customer Segment', hue='Ship Mode', kind='point')

# %% [markdown]
# ## Distribution Plot

# %%
sns.histplot(sales.Sales)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Count'>

# %%
sns.set(rc={"figure.figsize":(7, 4)})
sns.kdeplot(sales.Sales)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
sns.set(rc={"figure.figsize":(7, 4)})
sns.histplot(sales.Profit)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Count'>

# %%
sns.set(rc={"figure.figsize":(7, 4)})
sns.histplot(sales.Profit, kde=True)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Count'>

# %%
sns.set(rc={"figure.figsize":(7, 4)})
sns.histplot(sales.Profit)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Count'>

# %%
sns.histplot(sales.Profit[(sales.Region=='Ontario') & (sales.Profit>1000)], kde=True)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Count'>

# %%
sns.kdeplot(sales.Profit, bw_method=1000)   # bw = bandwidth
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %% [markdown]
# ## joint plot

# %%
sns.jointplot(x='Sales', y='Profit', data=sales)

# %%
sns.jointplot(x='Sales', y='Discount', data=sales)

# %%
sns.jointplot(x='Sales', y='Product Base Margin', data=sales)

# %%
sns.jointplot(x='Sales', y='Product Base Margin', data=sales, kind='hex')

# %%
sns.jointplot(x='Discount', y='Product Base Margin', data=sales, kind='hex')

# %%
sns.jointplot(x='Discount', y='Product Base Margin', data=sales, kind='kde')

# %% [markdown]
# ## Pairplot

# %%
sales.shape
# Out:
# (8390, 21)

# %%
temp_sales = sales.iloc[:1000, 4:15]
temp_sales.shape
# Out:
# (1000, 11)

# %%
sns.pairplot(temp_sales, hue='Ship Mode')

# %% [markdown]
# ## Heatmap

# %%
corr = np.corrcoef(np.random.randn(10, 200))
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
     f, ax = plt.subplots(figsize=(7, 5))
     ax = sns.heatmap(corr, vmax=.3, square=True)

# %%
corr = np.corrcoef(np.random.randn(10, 200))
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
     f, ax = plt.subplots(figsize=(10, 8))
     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True, annot=True)

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True, annot=True, cmap='BuPu')

# %%
# importing inbuilt datasets in seaborn
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
f, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(flights)

# %%
# importing inbuilt datasets in seaborn
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
f, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(flights, cmap='BuPu')
